# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv(r"C:\Users\mogha\Downloads\hotel_bookings 2.csv")
# Out:
# C:\Users\mogha\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# Data Cleaning
# Check for missing values
print("\nMissing Values:")
df.isnull().sum()
# Out:
# Missing Values:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# ...

# %%
duplicates=df.duplicated().sum()
print("\nNumber of Duplicate Rows:", duplicates)
# Out:
# Number of Duplicate Rows: 31994

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df['reservation_status_date']=pd.to_datetime(df['reservation_status_date'])

# %%
df.describe(include=object)
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
#  'CMR' 'BIH' 'MUS' 'COM' 'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI'
#  'SAU' 'VNM' 'PLW' 'QAT' 'EGY' 'PER' 'MLT' 'MWI' 'ECU' 'MDG' 'ISL' 'UZB'
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop(['company','agent'],axis=1,inplace=True)
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df['adr'].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
df=df[df['adr']<5000]

# %% [markdown]
# ## Data Analysis and Visualizations

# %%
cancelled_perc=df['is_canceled'].value_counts(normalize=True)
print(cancelled_perc)
# Out:
# 0    0.628653
# 1    0.371347
# Name: is_canceled, dtype: float64

# %%
plt.figure(figsize=(5,4))
plt.title("Reservation status count")
plt.bar(['not canceled','canceled'],df['is_canceled'].value_counts(),edgecolor='k',width=0.7)
# Out:
# <BarContainer object of 2 artists>

# %%
sns.countplot('is_canceled',data=df)
# Out:
# <AxesSubplot:xlabel='is_canceled', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 4))
ax1 = sns.countplot(x='hotel', hue='is_canceled', data=df, palette='Blues')
legend_labels, _ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1, 1))
plt.title('Reservation status in different hotels', size=20)
plt.xlabel("hotel")
plt.ylabel("number of reservations")
plt.show()

# %%
resort_hotel=df[df['hotel']=="Resort Hotel"]
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
city_hotel=df[df['hotel']=="City Hotel"]
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.582918
# 1    0.417082
# Name: is_canceled, dtype: float64

# %%
resort_hotel=resort_hotel.groupby("reservation_status_date")[['adr']].mean()
city_hotel=city_hotel.groupby("reservation_status_date")[['adr']].mean()

# %%
resort_hotel
# Out:
#                                 adr
# reservation_status_date
# 2014-11-18                 0.000000
# 2015-01-01                61.966667
# 2015-01-05               115.363333
# 2015-01-06               133.677143
# 2015-01-07                82.485455
# ...                             ...
# 2017-12-05               103.287534
# 2017-12-06               159.808929
# 2017-12-07               160.306275
# 2017-12-08               212.767222
# 2017-12-09               153.570000
#
# [913 rows x 1 columns]

# %%
# Grouping and calculating mean
resort_hotel = resort_hotel.groupby("reservation_status_date")[['adr']].mean()

# Accessing separately
reservation_dates = resort_hotel.index  # Accessing the index, which contains the reservation dates
adr_means = resort_hotel['adr']  # Accessing the 'adr' column, which contains the mean values

# Displaying separately
print("Reservation Dates:")
print(reservation_dates)

print("\nADR Means:")
print(adr_means)
# Out:
# Reservation Dates:
# DatetimeIndex(['2014-11-18', '2015-01-01', '2015-01-05', '2015-01-06',
#                '2015-01-07', '2015-01-08', '2015-01-09', '2015-01-10',
#                '2015-01-11', '2015-01-12',
#                ...
#                '2017-11-08', '2017-12-01', '2017-12-02', '2017-12-03',
#                '2017-12-04', '2017-12-05', '2017-12-06', '2017-12-07',
#                '2017-12-08', '2017-12-09'],
#               dtype='datetime64[ns]', name='reservation_status_date', length=913, freq=None)
#
# ADR Means:
# reservation_status_date
# 2014-11-18      0.000000
# 2015-01-01     61.966667
# 2015-01-05    115.363333
# 2015-01-06    133.677143
# 2015-01-07     82.485455
#                  ...
# 2017-12-05    103.287534
# 2017-12-06    159.808929
# 2017-12-07    160.306275
# 2017-12-08    212.767222
# 2017-12-09    153.570000
# Name: adr, Length: 913, dtype: float64

# %%
city_hotel
# Out:
#                                 adr
# reservation_status_date
# 2014-10-17                62.800000
# 2015-01-01                62.063158
# 2015-01-05                58.900000
# 2015-01-06                69.216667
# 2015-01-07                82.877500
# ...                             ...
# 2017-12-04               128.755465
# 2017-12-05               124.544536
# 2017-12-06               132.725882
# 2017-12-07               130.473617
# 2017-12-08               142.949080
#
# [864 rows x 1 columns]

# %%
resort_hotel.index
# Out:
# DatetimeIndex(['2014-11-18', '2015-01-01', '2015-01-05', '2015-01-06',
#                '2015-01-07', '2015-01-08', '2015-01-09', '2015-01-10',
#                '2015-01-11', '2015-01-12',
#                ...
#                '2017-11-08', '2017-12-01', '2017-12-02', '2017-12-03',
#                '2017-12-04', '2017-12-05', '2017-12-06', '2017-12-07',
#                '2017-12-08', '2017-12-09'],
#               dtype='datetime64[ns]', name='reservation_status_date', length=913, freq=None)

# %%
resort_hotel['adr']
# Out:
# reservation_status_date
# 2014-11-18      0.000000
# 2015-01-01     61.966667
# 2015-01-05    115.363333
# 2015-01-06    133.677143
# 2015-01-07     82.485455
#                  ...
# 2017-12-05    103.287534
# 2017-12-06    159.808929
# 2017-12-07    160.306275
# 2017-12-08    212.767222
# 2017-12-09    153.570000
# Name: adr, Length: 913, dtype: float64

# %%
plt.figure(figsize=(20,8))
plt.title("Averge Dily Rate in city and Resort Hotel",fontsize=30)
plt.plot(resort_hotel.index,resort_hotel['adr'],label="Resort Hotel")
plt.plot(city_hotel.index,city_hotel['adr'],label="City Hotel")
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# From the plotted data showing the average daily rate (ADR) for both the resort hotel and the city hotel over time, we can observe several potential insights:
#
# Seasonality: There may be visible patterns in the ADR over time, indicating seasonal variations in hotel pricing. For example, higher ADRs during peak tourist seasons and lower ADRs during off-peak periods suggest that hotels adjust their pricing strategies based on demand fluctuations.
#
# Price Differences: The comparison between the ADR of the resort hotel and the city hotel allows us to observe any consistent price differences between the two types of accommodations. A higher ADR for one type of hotel compared to the other may suggest differences in amenities, location, or target market.
#
# Trends: Trends in ADR over time can provide insights into the overall performance and market conditions of the hotels. Increasing ADRs may indicate a healthy demand for hotel rooms or successful pricing strategies, while decreasing ADRs might signal challenges in attracting guests or competing with other accommodations.
#
# Potential Events or Influences: Sudden spikes or drops in ADRs could be indicative of external factors such as special events, economic changes, or shifts in tourist preferences. These observations can help hotel managers understand the impact of such events on their pricing and revenue management strategies.
#
# Opportunities for Improvement: Analyzing ADR trends can help identify periods of underperformance or missed revenue opportunities. Hotels can use this information to adjust their pricing strategies, offer promotions, or enhance their services to better meet guest expectations and maximize revenue.
#
# Overall, visualizing the ADR data for both the resort hotel and the city hotel provides valuable insights into pricing dynamics, market trends, and opportunities for revenue optimization within the hospitality industry.

# %% [markdown]
# ## average price charged for accommodations, such as hotel rooms, vacation rentals, or other lodging options.

# %%
df['month']=df['reservation_status_date'].dt.month
plt.figure(figsize=(16,8))
ax1=sns.countplot(x='month',hue='is_canceled',data=df,palette='bright')
legend_labels,_ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title("reservation status per month",size=20)
plt.xlabel('month')
plt.ylabel('number of reservations')
plt.legend(['not_canceled','canceled'])
plt.show()

# %% [markdown]
# ## If price is higher then cancellation rate also higher

# %%
plt.figure(figsize=(15,8))
plt.title('ADR per month',fontsize=30)
sns.barplot('month','adr',data=df[df['is_canceled']==1].groupby('month')[['adr']].sum().reset_index())
plt.show()

# %%
cancelled_data = df[df['is_canceled']==1]
top_10_country=cancelled_data['country'].value_counts()[:10]
plt.figure(figsize=(8,8))
plt.title("Top 10 countries with reservation canceled")
plt.pie(top_10_country,autopct='%.2f',labels=top_10_country.index)
plt.show()

# %%
cancelled_data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 8       Resort Hotel            1         85               2015
# 9       Resort Hotel            1         75               2015
# 10      Resort Hotel            1         23               2015
# 27      Resort Hotel            1         60               2015
# 32      Resort Hotel            1         96               2015
# ...              ...          ...        ...                ...
# 110280    City Hotel            1        132               2017
# 111355    City Hotel            1          4               2017
# 111924    City Hotel            1          7               2017
# 111925    City Hotel            1          6               2017
# 117295    City Hotel            1          0               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 8                    July                        27
# 9                    July                        27
# ...

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %%
df['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: market_segment, dtype: float64

# %%
cancelled_data['market_segment'].value_counts()
# Out:
# Online TA        20738
# Groups           12097
# Offline TA/TO     8277
# Direct            1920
# Corporate          978
# Complementary       90
# Aviation            52
# Name: market_segment, dtype: int64

# %%
cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: market_segment, dtype: float64

# %%
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date',inplace=True)

not_cancelled_df = df[df['is_canceled']==0]
not_cancelled_df_adr = not_cancelled_df.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('reservation_status_date',inplace=True)

plt.figure(figsize=(20,6))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'],label='not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'],label='not cancelled')
plt.legend()
plt.show()

# %%
cancelled_df_adr=cancelled_df_adr[(cancelled_df_adr['reservation_status_date']> '2016')&(cancelled_df_adr['reservation_status_date']<'2018')]
not_cancelled_df_adr=not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date']>'2016')&(not_cancelled_df_adr['reservation_status_date']<'2018')]

# %%
plt.figure(figsize=(20,7))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'],label='not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'],label='cancelled')
plt.legend(fontsize=20)
